# %%
#Import necessary packages
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
# %matplotlib inline

# %%
#Enter original data from the problem
X = [0.0, 0.2, 0.4, 0.6, 0.65]
Y = [1.28, 0.94, 0.85, 1.32, 2.0] #Fa0/-rA (processed data)

# %%
#Plot the original data
plt.plot(X,Y)

# %%
#Smooth the plot using splines
X_new = np.linspace(0,0.65,10)
spl = interpolate.make_interp_spline(X,Y)
Y_new = spl(X_new)
plt.plot(X_new, Y_new)

# %%
#That didn't work very well. No time to troubleshoot now.
